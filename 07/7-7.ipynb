# %%
import math
import matplotlib.pyplot as plt

x0=10.0
x=[x0]
xa=[x0]
a=1.2
dt=0.01
t=[0]
for i in range(1,1000):
    xa.append(x0 * math.exp(a*dt*i))
    xx=x[i-1]+dt*a*x[i-1]
    x.append(xx)
    t.append(dt*i)
    
plt.plot(t, x)
plt.plot(t, xa)
