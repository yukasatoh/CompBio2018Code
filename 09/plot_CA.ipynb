# %% [markdown]
# # セル・オートマトンの結果プロット用ノートブック

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## データの読み込みとプロット

# %%
# データの読み込み
data = np.genfromtxt("./CA_9-5.csv", dtype="int",delimiter=",")

# %%
# プロット
plt.figure( figsize=(5, 5), dpi=120)
plt.matshow(data, cmap=plt.cm.gray, fignum=1)
plt.show()
